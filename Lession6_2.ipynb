# %% [markdown]
# <a href="https://colab.research.google.com/github/kig2929kig/ITQ/blob/main/Lession6_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip3 install ColabTurtle
import ColabTurtle.Turtle as turtle
import random

def square() :
  turtle.left(-90)
  turtle.forward(50)
  for i in range(3) :
    turtle.left(90)
    turtle.forward(50)

turtle.initializeTurtle()
#print(turtle.DEFAULT_WINDOW_SIZE)
turtle.speed(10)
color_list = ["red", "green", "blue", "yellow" ]
#help(turtle)
for x in range(50, 800, 50) :
  for y in range(50,500, 50) :
    turtle.penup()
    turtle.goto(x, y)
    turtle.pendown()
    turtle.color(random.choice(color_list))
    square()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
#!pip3 install ColabTurtle
import ColabTurtle.Turtle as t
import random as r

t.initializeTurtle()

t.bgcolor(255,255,255)
t.pu()
t.speed(10)

for x in range(50-8, 800-9, 50) :
    for y in range(50, 500, 50) :
        t.goto(x,y)
        t.color(r.randint(0,255),r.randint(0,255),r.randint(0,255))
        t.write('★', font=(20, "Arial", "normal"))
t.ht()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="rgb(255,255,255)"/>
# ...

# %%
#!pip3 install ColabTurtle
import ColabTurtle.Turtle as turtle
import random
x, y, n = 0, 0, 0

turtle.initializeTurtle()
turtle.speed(13)
#help(turtle)
while True :
  turtle.color((random.randint(155,255)),(random.randint(155,255)),(random.randint(155,255)))
  turtle.penup()
  turtle.setx(random.randint(50,750))
  turtle.sety(random.randint(50,450))
  turtle.pendown()
  turtle.forward(13)
  turtle.left(144)
  turtle.forward(13)
  turtle.left(144)
  turtle.forward(13)
  turtle.left(144)
  turtle.forward(13)
  turtle.left(144)
  turtle.forward(13)
  n = n + 1
  if n == 100 :
    break
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
#!pip3 install ColabTurtle
import ColabTurtle.Turtle as turtle
import random

turtle.initializeTurtle()

turtle.left(-90)
turtle.forward(50)
for i in range(3) :
  turtle.left(90)
  turtle.forward(50)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="450.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="450.0" y1="250.0" x2="450.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="450.0" y1="200.0" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="200.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(180,400.0,250.0) translate(382.0, 232.0)">
# ...
